# %%
from pathlib import Path
# !pip install gradio
import gradio as gr
# !pip install diffusers
# !pip install transformers
# !pip install stable_diffusion_videos[realesrgan]
from stable_diffusion_videos import generate_images
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.8/15.8 MB 52.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.5/84.5 KB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 KB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.8/199.8 KB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 28.5 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.8/57.8 KB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.1/57.1 KB 3.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.7/45.7 KB 3.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.5/106.5 KB 3.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 KB 4.5 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# Token is valid.
# Your token has been saved in your configured git credential helpers (store).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %% [markdown]
# Hugging face token: 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

# %%
import torch

from stable_diffusion_videos import StableDiffusionWalkPipeline

pipeline = StableDiffusionWalkPipeline.from_pretrained(
    "CompVis/stable-diffusion-v1-4",
    torch_dtype=torch.float16,
    revision="fp16",
).to("cuda")
# Out:
# ...
# Fetching 16 files:   0%|          | 0/16 [00:00<?, ?it/s]
# ...
# Cannot initialize model with low cpu memory usage because `accelerate` was not found in the environment. Defaulting to `low_cpu_mem_usage=False`. It is strongly recommended to install `accelerate` for faster and less memory-intense model loading. You can do so with:
# ```
# pip install accelerate
# ```
# .
# `text_config_dict` is provided which will be used to initialize `CLIPTextConfig`. The value `text_config["id2label"]` will be overriden.

# %%
connect_google_drive = True 
if connect_google_drive:
    from google.colab import drive

    drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
class Interface:
    def __init__(self, pipeline):
        self.pipeline = pipeline
        self.interface_images = gr.Interface(
            self.fn_images,
            inputs=[
                
                gr.Textbox("", label='Prompt'),
                gr.Slider(1, 24, 1, step=1, label='Batch size'),
                gr.Slider(1, 16, 1, step=1, label='# Batches'),
                gr.Slider(10, 100, 50, step=1, label='# Inference Steps'),
                gr.Slider(5.0, 15.0, 7.5, step=0.5, label='Guidance Scale'),
                gr.Slider(512, 1024, 512, step=64, label='Height'),
                gr.Slider(512, 1024, 512, step=64, label='Width'),
                gr.Checkbox(False, label='Upsample'),
                gr.Textbox("/content/gdrive/MyDrive/ResultsImages", label='Output directory to save results to'),
                # gr.Checkbox(False, label='Push results to Hugging Face Hub'),
                # gr.Textbox("", label='Hugging Face Repo ID to push images to'),
            ],
            outputs=gr.Gallery(),
        )

        self.interface_videos = gr.Interface(
            self.fn_videos,
            inputs=[

                gr.Textbox("blueberry spaghetti\nstrawberry spaghetti", lines=2, label='Prompts, separated by new line'),
                gr.Textbox("42\n1337", lines=2, label='Seeds, separated by new line'),
                gr.Slider(3, 1000, 5, step=1, label='# Interpolation Steps between prompts'),
                gr.Slider(3, 60, 5, step=1, label='Output Video FPS'),
                gr.Slider(1, 24, 1, step=1, label='Batch size'),
                gr.Slider(10, 100, 50, step=1, label='# Inference Steps'),
                gr.Slider(5.0, 15.0, 7.5, step=0.5, label='Guidance Scale'),
                gr.Slider(512, 1024, 512, step=64, label='Height'),
                gr.Slider(512, 1024, 512, step=64, label='Width'),
                gr.Checkbox(False, label='Upsample'),
                gr.Textbox("/content/gdrive/MyDrive/ResultsVideos", label='Output directory to save results to'),
            ],
            outputs=gr.Video(),
        )
        self.interface = gr.TabbedInterface(
            [self.interface_images, self.interface_videos],
            ['Images'],
        )
    
    def fn_videos(
        self,
        prompts,
        seeds,
        num_interpolation_steps,
        fps,
        batch_size,
        num_inference_steps,
        guidance_scale,
        height,
        width,
        upsample,
        output_dir,
    ):
        prompts = [x.strip() for x in prompts.split('\n') if x.strip()]
        seeds = [int(x.strip()) for x in seeds.split('\n') if x.strip()]

        return self.pipeline.walk(
            prompts=prompts,
            seeds=seeds,
            num_interpolation_steps=num_interpolation_steps,
            fps=fps,
            height=height,
            width=width,
            output_dir=output_dir,
            guidance_scale=guidance_scale,
            num_inference_steps=num_inference_steps,
            upsample=upsample,
            batch_size=batch_size
        )

    def fn_images(
        self,
        prompt,
        batch_size,
        num_batches,
        num_inference_steps,
        guidance_scale,
        height,
        width,
        upsample,
        output_dir,
        repo_id=None,
        push_to_hub=False,
    ):
        image_filepaths = generate_images(
            self.pipeline,
            prompt,
            batch_size=batch_size,
            num_batches=num_batches,
            num_inference_steps=num_inference_steps,
            guidance_scale=guidance_scale,
            output_dir=output_dir,
            image_file_ext='.jpg',
            upsample=upsample,
            height=height,
            width=width,
            push_to_hub=push_to_hub,
            repo_id=repo_id,
            create_pr=False,
        )
        return [(x, Path(x).stem) for x in sorted(image_filepaths)]
        
    def launch(self, *args, **kwargs):
        self.interface.launch(*args, **kwargs)

# %%
interface = Interface(pipeline)
interface.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://8fdbd173b0901db360.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades (NEW!), check out Spaces: https://huggingface.co/spaces
# <div><iframe src="https://8fdbd173b0901db360.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
